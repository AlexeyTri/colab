# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexeyTri/colab/blob/master/Learn_Yolo8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/drive/MyDrive/Personal_safety_yolov8.zip -d dataset_Yolo
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#  extracting: dataset_Yolo/valid/labels/Nhh_img_81_jpg.rf.00246985c5c7ad8dc25b42da335983b9.txt
#  extracting: dataset_Yolo/valid/labels/OR-02-01-0743-26_l_jpg.rf.681a067704e99b34bb09070a0af0a889.txt
#  extracting: dataset_Yolo/valid/labels/PP02img1021_jpg.rf.a81789c98569d276c7292e381d7f2b53.txt
#  extracting: dataset_Yolo/valid/labels/PP02img1022_jpg.rf.75c748a8116491c04052cc101b2bbba5.txt
#  extracting: dataset_Yolo/valid/labels/PP02img1030_jpg.rf.551edb6ab58a76f56302d6fd8c7ea2cd.txt
#  extracting: dataset_Yolo/valid/labels/PP02img1035_jpg.rf.6ba4264d81ef95a06c1af4937e0da04b.txt
#  extracting: dataset_Yolo/valid/labels/PP02img1037_jpg.rf.7b6eef01ad33a43772beaf9303bd13b6.txt
#  extracting: dataset_Yolo/valid/labels/PP02img1045_jpg.rf.5a9d98d53ab9bf1ada473920e6fefd01.txt
#  extracting: dataset_Yolo/valid/labels/PP02img1047_jpg.rf.dcaeadb2b377f0ffa71dc5adb36d5327.txt
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.6/490.6 KB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 KB 19.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='/content/eed224d535d1841aa42d604d33fa4b07.jpg'
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 247MB/s]
# 2023-04-04 10:32:09.709695: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 10:32:10.953540: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# image 1/1 /content/eed224d535d1841aa42d604d33fa4b07.jpg: 416x640 1 person, 1468.5ms
# Speed: 1.2ms preprocess, 1468.5ms inference, 32.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/dataset_Yolo/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# ...
